# %%
import cv2
from google.colab.patches import cv2_imshow
img=cv2.imread('/content/abi.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=96x96>

# %%
img=cv2.imread('/content/abi.jpg',0)
grey_img=255-img
cv2_imshow(grey_img)
# Out:
# <PIL.Image.Image image mode=L size=96x96>

# %%
img=cv2.imread('/content/abi.jpg',0)
reshape_img=cv2.resize(img,(400,400))
cv2_imshow(reshape_img)
# Out:
# <PIL.Image.Image image mode=L size=400x400>

# %%
img=cv2.imread('/content/abi.jpg',0)
resize_img=cv2.resize(img,(int(img.shape[1]/2),int(img.shape[0]/2)))
cv2_imshow(resize_img)
# Out:
# <PIL.Image.Image image mode=L size=48x48>
